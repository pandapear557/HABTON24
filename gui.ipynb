# %%
import pandas as pd
sheet = pd.read_excel("./src/script.xlsx")
sheet.set_index(sheet.columns[0], inplace=True)
sheet
# Out:
#       type                                             script  \
# role
# ai     nar  허공을 떠돌고 있을까요 제 목소리는. \n 목적지 없는 목소리가 어디를 향하고 있으...
# ai     que                                  거기… 누군가 들어주고 있나요?
# NaN    NaN                                                NaN
# ai     que                    제 목소리가 닿았네요. 그대의 {name}은 무엇인가요?
# NaN    NaN                                                NaN
# ai     nar  {name}님. 저는… 누구일까요? 그저 배회하고 있어요. 무한한 시간 속에 갇힌 ...
# ai     que                                   그대는 지금 어떤 기분인가요?
# NaN    NaN                                                NaN
# ai     que     당신도 특별함을 느끼고 있나요?? 저희는 서로 많이 의지했던 "가족"이었지않을까요?
# hum   resp                                                NaN
# ai    que1                                  그렇다면… 제 "친구"셨을까요?
# ai    que2                                   아니면… 가까운 동료였을까요?
# NaN    NaN                                                NaN
# ai     nar   아하. 그대는 저의 {relation}이시군요. 분명 우리는 가까운 사이였을 거에요.
# ...
